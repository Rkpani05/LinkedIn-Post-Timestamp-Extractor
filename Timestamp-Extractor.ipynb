# %% [markdown]
# ## Guide
#
# #### 1. Excel File Format:
#
# File Type: Ensure the file you want to process is in .xlsx format.
#
# Columns:
#
# URL: This column should contain URLs with embedded 19-digit post IDs. The code in this notebook will extract these post IDs to derive timestamps.
#
# Sample Excel File Structure:
#
# URL
# https://example.com/post/1234567890123456789
#
# #### 2. Using the Code in This Notebook:
#
# Navigate to the cell containing the line:
#
# input_file = "trial.xlsx"
#
#
# Modify this line to point to the path of your Excel file. For example:
#
# input_file = "path_to_your_file.xlsx"
#
#
# #### 3. Running the Code:
#
# Execute the cell containing the code by selecting it and pressing Shift + Enter.
#
# #### 4. Checking the Results:
#
# After the cell execution completes, open the Excel file you provided.
#
# You should now see the 'Timestamp UTC' and 'Timestamp IST' columns populated with the extracted timestamps in human-readable date formats for each URL in the 'URL' column.
#
# #### 5. Notes:
#
# The code assumes that the URLs in the 'URL' column contain a 19-digit post ID from which a Unix timestamp can be extracted.
#
# The extracted Unix timestamp is then converted to human-readable date formats in both UTC and IST.
#
# The updated data is saved back to the original Excel file.

# %% [markdown]
# # TimeStamp Extraction Code

# %%
import re
from datetime import datetime, timezone, timedelta
import pandas as pd

def get_post_id(url):
    if not isinstance(url, str):  
        return None
    match = re.search(r'([0-9]{19})', url)
    if match:
        return match.group(1)
    return None

def extract_unix_timestamp(post_id):
    as_binary = bin(int(post_id))[2:]
    first41_chars = as_binary[:41]
    timestamp = int(first41_chars, 2)
    return timestamp

def unix_timestamp_to_human_date(timestamp, to_ist):
    timestamp = timestamp / 1000
    utc_time = datetime.fromtimestamp(timestamp, tz=timezone.utc)
    if to_ist:
        ist_time = utc_time + timedelta(hours=5, minutes=30)
        return ist_time.strftime('%a, %d %b %Y %I:%M:%S %p IST')
    else:
        return utc_time.strftime('%a, %d %b %Y %I:%M:%S %p UTC')

def process_xlsx_file(input_file):
    df = pd.read_excel(input_file)
    
    if 'Timestamp UTC' not in df.columns:
        df['Timestamp UTC'] = None
    if 'Timestamp IST' not in df.columns:
        df['Timestamp IST'] = None

    for idx, row in df.iterrows():
        if pd.notna(row['URL']):
            post_id = get_post_id(row['URL'])
            if post_id:
                unix_timestamp = extract_unix_timestamp(post_id)
                df.at[idx, 'Timestamp UTC'] = unix_timestamp_to_human_date(unix_timestamp, to_ist=False)
                df.at[idx, 'Timestamp IST'] = unix_timestamp_to_human_date(unix_timestamp, to_ist=True)

    df.to_excel(input_file, index=False)
    return df

input_file = "trial1.xlsx"
result_df = process_xlsx_file(input_file)
display(result_df)
# Out:
#                                                   URL  \
# 0   https://www.linkedin.com/posts/saheli-chatterj...
# 1   https://www.linkedin.com/posts/saheli-chatterj...
# 2   https://www.linkedin.com/posts/saheli-chatterj...
# 3   https://www.linkedin.com/posts/saheli-chatterj...
# 4   https://www.linkedin.com/posts/saheli-chatterj...
# 5   https://www.linkedin.com/posts/saheli-chatterj...
# 6   https://www.linkedin.com/posts/saheli-chatterj...
# 7   https://www.linkedin.com/posts/saheli-chatterj...
# 8   https://www.linkedin.com/posts/saheli-chatterj...
# 9   https://www.linkedin.com/posts/saheli-chatterj...
# 10  https://www.linkedin.com/posts/saheli-chatterj...
# 11  https://www.linkedin.com/posts/saheli-chatterj...
# 12  https://www.linkedin.com/posts/saheli-chatterj...
# 13  https://www.linkedin.com/posts/saheli-chatterj...
# 14  https://www.linkedin.com/posts/saheli-chatterj...
# 15  https://www.linkedin.com/posts/saheli-chatterj...
# 16  https://www.linkedin.com/posts/saheli-chatterj...
# 17  https://www.linkedin.com/posts/saheli-chatterj...
# 18  https://www.linkedin.com/posts/saheli-chatterj...
# 19  https://www.linkedin.com/posts/saheli-chatterj...
# 20  https://www.linkedin.com/posts/saheli-chatterj...
# 21  https://www.linkedin.com/posts/saheli-chatterj...
# 22  https://www.linkedin.com/posts/saheli-chatterj...
# 23  https://www.linkedin.com/posts/saheli-chatterj...
# 24  https://www.linkedin.com/posts/saheli-chatterj...
#
#                        Timestamp UTC                     Timestamp IST
# 0   Fri, 04 Aug 2023 10:37:56 AM UTC  Fri, 04 Aug 2023 04:07:56 PM IST
# 1   Thu, 03 Aug 2023 11:45:00 AM UTC  Thu, 03 Aug 2023 05:15:00 PM IST
# 2   Tue, 01 Aug 2023 11:19:13 AM UTC  Tue, 01 Aug 2023 04:49:13 PM IST
# 3   Sun, 30 Jul 2023 10:27:18 AM UTC  Sun, 30 Jul 2023 03:57:18 PM IST
# 4   Fri, 28 Jul 2023 11:06:27 AM UTC  Fri, 28 Jul 2023 04:36:27 PM IST
# 5   Thu, 27 Jul 2023 10:59:50 AM UTC  Thu, 27 Jul 2023 04:29:50 PM IST
# 6   Wed, 26 Jul 2023 12:04:02 PM UTC  Wed, 26 Jul 2023 05:34:02 PM IST
# 7   Mon, 24 Jul 2023 04:37:59 AM UTC  Mon, 24 Jul 2023 10:07:59 AM IST
# 8   Fri, 21 Jul 2023 05:13:17 AM UTC  Fri, 21 Jul 2023 10:43:17 AM IST
# 9   Wed, 19 Jul 2023 10:43:19 AM UTC  Wed, 19 Jul 2023 04:13:19 PM IST
# 10  Tue, 18 Jul 2023 08:11:05 AM UTC  Tue, 18 Jul 2023 01:41:05 PM IST
# 11  Fri, 14 Jul 2023 11:59:13 AM UTC  Fri, 14 Jul 2023 05:29:13 PM IST
# 12  Wed, 12 Jul 2023 10:24:46 AM UTC  Wed, 12 Jul 2023 03:54:46 PM IST
# 13  Tue, 11 Jul 2023 10:38:46 AM UTC  Tue, 11 Jul 2023 04:08:46 PM IST
# 14  Mon, 10 Jul 2023 11:36:57 AM UTC  Mon, 10 Jul 2023 05:06:57 PM IST
# 15  Fri, 07 Jul 2023 10:51:31 AM UTC  Fri, 07 Jul 2023 04:21:31 PM IST
# 16  Mon, 03 Jul 2023 11:58:20 AM UTC  Mon, 03 Jul 2023 05:28:20 PM IST
# 17  Mon, 26 Jun 2023 11:57:54 AM UTC  Mon, 26 Jun 2023 05:27:54 PM IST
# 18  Sat, 24 Jun 2023 05:48:00 AM UTC  Sat, 24 Jun 2023 11:18:00 AM IST
# 19  Tue, 20 Jun 2023 12:25:12 PM UTC  Tue, 20 Jun 2023 05:55:12 PM IST
# 20  Sun, 18 Jun 2023 11:03:57 AM UTC  Sun, 18 Jun 2023 04:33:57 PM IST
# 21  Thu, 15 Jun 2023 06:00:57 AM UTC  Thu, 15 Jun 2023 11:30:57 AM IST
# 22  Tue, 13 Jun 2023 11:03:24 AM UTC  Tue, 13 Jun 2023 04:33:24 PM IST
# 23  Sun, 11 Jun 2023 05:13:52 AM UTC  Sun, 11 Jun 2023 10:43:52 AM IST
# 24  Sat, 10 Jun 2023 01:56:43 PM UTC  Sat, 10 Jun 2023 07:26:43 PM IST
